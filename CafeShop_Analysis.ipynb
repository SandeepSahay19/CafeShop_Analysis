# %% [markdown]
# # CAFE SHOP SALES ANALYSIS

# %% [markdown]
# ## ABOUT THE DATASET

# %% [markdown]
# ### The Dataset is about the cake shop sales over first quarter of year 2019, meaning first three months (january, february and march). The Dataset consist of five columns namely as  Date, Items, Unit Price, Quantity and Price. Using POWER BI I have to find Insights related to sales.

# %% [markdown]
# ### I have to find insights related to stakeholder's questions. Questions are mentioned below.

# %% [markdown]
# ## QUESTIONS :

# %% [markdown]
# ## 1. What is total number of quantity sold of different items? What are the top items with most quantity sold ?

# %% [markdown]
#  ### DAX function to calculate sum of quantity :
#  ### Total Quantity = SUM('CakeShop'[Quantity])

# %% [markdown]
# ### created new measure named as Total Quantity, adding Total Quantity and Items to visual.

# %% [markdown]
# ## 2. What is Average Price for different item? Top Itmes with highest average Price?

# %% [markdown]
# ### DAX function to calculate averge price :
# ### Average Price = AVERAGE('CakeShop'[Price])

# %% [markdown]
# ### Created new measure Average Price , adding Average Price and Items in the visual to show the Average Prices of different Item.

# %% [markdown]
# ## 3. Which Item collected the Highest Revenue? Top Items with highest revenues?

# %% [markdown]
# ### DAX Function to calculate Total Revenue :

# %% [markdown]
# ### Total Revenue = SUMX('CakeShop', 'CakeShop'[Quantity] * 'CakeShop'[Price])

# %% [markdown]
# ### Created New Measure Total Revenue , adding Total Revenue and Items in the visual to get Total Revenue of different Items.

# %% [markdown]
# ## 4.Total Revenue in different months? Which Month saw highest revenue collection ?

# %% [markdown]
# ### DAX Function to calculate Total Revenue for different months:
# ### Total Revenue = SUMX('CakeShop', 'CakeShop'[Quantity] * 'CakeShop'[Price])
# ### adding Total Revenue and Date in the visual to calculate Total Revenue for different months

# %% [markdown]
# # DASHBOARD CONTAINING KPI'S(Key Performance Factor), the insights related to questions asked by StakeHolders

# %% [markdown]
# ![2023-06-03.png](attachment:2023-06-03.png)

# %% [markdown]
# # SUMMARY OF INSIGHTS :

# %% [markdown]
# - TOP 10 Items With highest amount of quantity sold:-
# - 1. Hot chocolate fudge (8409)
# - 2. Vanila double scoop (6384)
# - 3. Cake Fudge (6057)
# - 4. Vanila single scoop (4344)
# - 5. Butterscotch single scoop (4318)
# - 6. Death by chocolate (4221)
# - 7. Cafe Caramel (2189)
# - 8. Dry fruit double scoop (513)
# - 9. Pista Double scoop (464)
# -10. Dry fruit single scoop (451)

# %% [markdown]
# - Top 10 Items with Highest Average Price:-
# - 1.Death by chocolate (541.15)
# - 2.Trilogy (528.89)
# - 3.Cafe Caramel (495.39)
# - 4.Cafe Fudge (447.34)
# - 5.Almond Fudge (426.76)
# - 6.Banana Split (410.00)
# - 7.Dew Drop Sundae (402.08)
# - 8.Mint Fudge (382.15)
# - 9.Hot chocolate fudge (362.72)
# -10.Chocolate Europa Douple Scoop (315.33)

# %% [markdown]
# - Top 10 Items with highest Total Revenue :-
# - 1.Hot Chocaolate Fudge (3711000)
# - 2.Cake Fudge (3325350)
# - 3.Death by Chocolate (2785860)
# - 4.Vanilla Double scoop (1885440)
# - 5.Cafe Caramel (1317600)
# - 6.Butterscotch Single Scoop (970440)
# - 7.Vanilla single scoop (800800)
# - 8.Dry Fruit Double scoop (173970)
# - 9.Chocolate Europa Double Scoop (162400)
# -10.Pista double scoop (158760)

# %% [markdown]
# - Total Revenue in different months:-
# - January (1421330) 31.01 % of Total revenue of first 3 months.
# - February (1422350) 31.03 % of Total revenue of first 3 months.
# - March (1739590) 37.96 % of Total revenue of first 3 months.
